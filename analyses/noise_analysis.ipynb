# %%
import numpy.random as npr

# %%
import os
import subprocess
import donuts.deconv.utils as du
import nibabel as nib
import numpy as np
import numpy.random as npr
import scipy.optimize as spo
os.chdir('/root/data')

# %%
subprocess.check_output('aws s3 cp s3://rawpredator/chris1/8631_5_coil8_ec.nii.gz 8631_5_coil8_ec.nii.gz', shell=True)
0

# %%
subprocess.check_output('aws s3 cp s3://chris1data/chris1_bvec.csv .', shell=True)
# Out:
# 'download: s3://chris1data/chris1_bvec.csv to ./chris1_bvec.csv\n'

# %%
coil_data = nib.load('/root/data/8631_5_coil8_ec.nii.gz').get_data()

# %%
bvecs = np.loadtxt('/root/data/chris1_bvec.csv').T

# %%
b0_inds = np.where(sum(bvecs**2, 1) == 0)[0]
b0_inds = b0_inds[2:]
b0_inds
# Out:
# array([ 16,  31,  46,  61,  75,  90, 105, 120, 135, 149])

# %%
b0_data = coil_data[:, :, :, b0_inds]

# %%
np.shape(b0_data)
# Out:
# (120, 120, 69, 10)

# %%
b0_sum = np.squeeze(apply_over_axes(sum, np.absolute(b0_data), 3))

# %%
np.shape(b0_sum)
# Out:
# (120, 120, 69)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(b0_sum.ravel())
# Out:
# (array([  9.56445000e+05,   2.71440000e+04,   6.52800000e+03,
#           1.89300000e+03,   8.38000000e+02,   4.13000000e+02,
#           1.88000000e+02,   9.40000000e+01,   4.30000000e+01,
#           1.40000000e+01]),
#  array([  7.09532760e-04,   1.14228874e+01,   2.28450653e+01,
#           3.42672432e+01,   4.56894211e+01,   5.71115990e+01,
#           6.85337769e+01,   7.99559547e+01,   9.13781326e+01,
#           1.02800311e+02,   1.14222488e+02]),
#  <a list of 10 Patch objects>)

# %%
mask = b0_sum > 10

# %%
np.shape(mask), np.sum(mask.ravel())
# Out:
# ((120, 120, 69), 45353)

# %%
temp_map = mask
z_inds = [10, 20, 30, 40, 50]
f_c1, axarr = plt.subplots(1, len(z_inds), sharex=True, sharey=True, figsize = (15, 3))
for j in range(len(z_inds)):
    z_ind = z_inds[j]
    axarr[j].imshow(temp_map[:, :, z_ind], cmap='bone', vmin = -0.2, vmax = 1.0)

# %%
m_coords = np.array(np.unravel_index(np.where(mask.ravel()==1)[0], np.shape(mask))).T

# %%
m_vox = np.hstack([m_coords, np.array([b0_data[c[0], c[1], c[2], :] for c in m_coords])])

# %%
np.shape(m_vox)
# Out:
# (45353, 13)

# %%
np.savetxt('/root/data/flat.txt', m_vox, fmt = '%.9e')

# %%
os.chdir('/root/ephemeral-hdfs/bin')
os.system('./hadoop fs -put /root/data/flat.txt flat.txt')
# Out:
# 0

# %%
parts = 100
rawrdd = sc.textFile('flat.txt', parts)

# %%
rawrdd.first()
# Out:
# u'2.200000000e+01 7.100000000e+01 4.800000000e+01 1.105130911e+00 1.075275779e+00 1.074442148e+00 1.031464815e+00 1.112839818e+00 1.111784697e+00 1.075066566e+00 1.138390660e+00 1.018763542e+00 1.052636862e+00'

# %%
m_vox[0, :]
# Out:
# array([ 22.        ,  71.        ,  48.        ,   1.10513091,
#          1.07527578,   1.07444215,   1.03146482,   1.11283982,
#          1.1117847 ,   1.07506657,   1.13839066,   1.01876354,   1.05263686])

# %%
varis = np.apply_over_axes(np.var, m_vox[:, 3:], 1)

# %%
plt.plot(sorted(varis)[:20000])

# %%
vthres = 0.015
def varfilt(st):
    temp = np.array([float(v) for v in str(st).split(' ')])[3:]
    return np.var(temp) > vthres

# %%
filt_rdd = rawrdd.filter(varfilt)

# %%
filt_rdd.count()
# Out:
# 22967

# %%
def standardize(x):
    return (x - np.mean(x))/np.std(x)

# %%
def par(st):
    temp = np.array([float(v) for v in str(st).split(' ')])[3:]
    return standardize(temp)

# %%
no_rdd = filt_rdd.map(par)

# %%
from pyspark.mllib.clustering import KMeans

# %%
model = KMeans.train(no_rdd, 3)

# %%
print "Final centers: " + str(model.clusterCenters)
# Out:
# Final centers: [array([-0.32408631,  0.36552621, -0.20292949, -0.06874242,  0.19653866,
#        -0.13214124,  0.48951767,  0.26096654, -0.20991814, -0.37473149]), array([ 0.87182399,  0.65242047,  0.77066202,  0.55853318, -0.21836491,
#         0.00832605, -0.1882659 , -0.53998286, -0.86526858, -1.04988346]), array([-0.56753894, -0.7407086 , -0.60762476, -0.48827681,  0.10587503,
#         0.00351896, -0.05442669,  0.3306422 ,  0.94081964,  1.07771997])]

# %%
labels = no_rdd.map(lambda x : model.predict(x)).collect()

# %%
plt.hist(labels)
# Out:
# (array([ 5175.,     0.,     0.,     0.,     0.,  9238.,     0.,     0.,
#             0.,  8554.]),
#  array([ 0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2,  1.4,  1.6,  1.8,  2. ]),
#  <a list of 10 Patch objects>)

# %%
def clas(st):
    coords = np.array([float(v) for v in str(st).split(' ')])[:3]
    temp = np.array([float(v) for v in str(st).split(' ')])[3:]
    if np.var(temp) > vthres:
        temp = temp - np.mean(temp)
        temp = temp/np.sqrt(np.var(temp))
        return model.predict(temp)
    else:
        return -1

# %%
labels = rawrdd.map(clas).collect()

# %%
plt.hist(labels)
# Out:
# (array([ 22386.,      0.,      0.,   5175.,      0.,      0.,   9238.,
#              0.,      0.,   8554.]),
#  array([-1. , -0.7, -0.4, -0.1,  0.2,  0.5,  0.8,  1.1,  1.4,  1.7,  2. ]),
#  <a list of 10 Patch objects>)

# %%
len(labels)
# Out:
# 45353

# %%
label_map = -2*np.ones(np.shape(mask))
for i in range(len(labels)):
    c = m_coords[i, :]
    label_map[c[0], c[1], c[2]] = labels[i]

# %%
temp_map = label_map
z_inds = [40, 45, 50, 55, 60]
f_c1, axarr = plt.subplots(1, len(z_inds), sharex=True, sharey=True, figsize = (18, 4))
for j in range(len(z_inds)):
    z_ind = z_inds[j]
    axarr[j].imshow(temp_map[:, :, z_ind], cmap='jet', vmin = -2, vmax = 3)

# %%
subv = m_vox[np.array(labels) == 0, :]
#subv_s = np.array([standardize(x[3:]) for x in subv])
subv_s = subv[:, 3:]

# %%
seq = npr.randint(0, np.shape(subv_s)[0], 5)
plt.plot(range(10), subv_s[seq[0],:],
         range(10), subv_s[seq[1],:],
         range(10), subv_s[seq[2],:],
         range(10), subv_s[seq[3],:],
         range(10), subv_s[seq[4],:])
# Out:
# [<matplotlib.lines.Line2D at 0x7ff37442f950>,
#  <matplotlib.lines.Line2D at 0x7ff37442fbd0>,
#  <matplotlib.lines.Line2D at 0x7ff37443e2d0>,
#  <matplotlib.lines.Line2D at 0x7ff37443e910>,
#  <matplotlib.lines.Line2D at 0x7ff37443ef50>]
